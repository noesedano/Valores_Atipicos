# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
data
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
data1=pd.read_csv("precios y productos_nulos.csv")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 1426 non-null   int64
#  1   CVE_DOC                    1426 non-null   object
#  2   FECHA_DOC                  1426 non-null   object
#  3   NOMBRE_VENDEDOR            1426 non-null   object
#  4   NOMBRE_CLIENTE             1426 non-null   object
#  5   CANT                       1426 non-null   int64
#  6   CVE_ART                    1426 non-null   object
#  7   DESCR                      1426 non-null   object
#  8   PRECIO_UNITARIO            1426 non-null   float64
#  9   COSTO_UNITARIO             1426 non-null   float64
#  10  COSTO_UNITARIO_CALCULADO   1426 non-null   float64
#  11  SUBTOTAL_PARTIDA           1426 non-null   float64
#  12  COSTO_TOTAL_CALCULADO      1426 non-null   float64
# ...

# %%
#identificar  valores nulos por columna
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                   0
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE_VENDEDOR              0
# NOMBRE_CLIENTE               0
# CANT                         0
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
#identificar  valores nulos por dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                   0
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE_VENDEDOR              0
# NOMBRE_CLIENTE               0
# CANT                         0
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
#identificar  valores nulos por columna
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                   0
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE_VENDEDOR              0
# NOMBRE_CLIENTE               0
# CANT                         0
# CVE_ART                      0
# DESCR                        0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
#se crean 2 dataframe para poder procesar los outliers
cuantitativas=data1.iloc[:, [5,8,9,10,11,12,13,14]]
cualitativas=data1.iloc [:, [1,2,3,4,6,7]]

# %%
cuantitativas
# Out:
#       CANT  PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0        1           434.48           52.80                     52.80
# 1        1          1264.05          327.18                    327.18
# 2        7           551.61          177.68                    177.68
# 3        1           140.00           38.96                     38.96
# 4        2           172.41          101.71                    101.71
# ...    ...              ...             ...                       ...
# 1421     6           712.00          102.31                    102.31
# 1422     6           718.60          104.69                    104.69
# 1423     3          2182.35            0.00                    596.55
# 1424     1          5909.84         1884.35                   1884.35
# 1425    10          1406.00            0.00                     80.66
#
#       SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# ...

# %%
cuantitativas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426 entries, 0 to 1425
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CANT                       1426 non-null   int64
#  1   PRECIO_UNITARIO            1426 non-null   float64
#  2   COSTO_UNITARIO             1426 non-null   float64
#  3   COSTO_UNITARIO_CALCULADO   1426 non-null   float64
#  4   SUBTOTAL_PARTIDA           1426 non-null   float64
#  5   COSTO_TOTAL_CALCULADO      1426 non-null   float64
#  6   MARGEN_UNITARIO_CALCULADO  1426 non-null   float64
#  7   MARGEN_TOTAL_CALCULADO     1426 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 89.3 KB

# %%
cualitativas
# Out:
#      CVE_DOC   FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034  2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036  2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041  2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042  2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043  2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...         ...                        ...
# 1421  F39834  2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834  2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835  2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837  2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838  2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE       CVE_ART  \
# 0               PÚBLICO EN GENERAL      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS        TP0007
# 3             OMAR RODRIGUEZ GOMEZ        TP0001
# 4               PÚBLICO EN GENERAL       BP00242
# ...

# %%
#realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas.plot(kind='box', vert=False)
plt.title("valores_atipicos_dataframe")
plt.show() #dibujamos el diagrama

# %% [markdown]
# procedimiento desviacion estandar para eliminar outliers en dataframe

# %%
#metodo aplicando desviacion estandar. encuentro los valores extremos }
y=cuantitativas
Limite_Superior= y.mean() + 3*y.std()
Limmite_Inferior = y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limmite_Inferior)
# Out:
# Limite superior permitido CANT                            22.531793
# PRECIO_UNITARIO               9533.970813
# COSTO_UNITARIO                3313.473534
# COSTO_UNITARIO_CALCULADO     16686.790475
# SUBTOTAL_PARTIDA             31402.663810
# COSTO_TOTAL_CALCULADO        18629.377526
# MARGEN_UNITARIO_CALCULADO    16001.398440
# MARGEN_TOTAL_CALCULADO       28691.369713
# dtype: float64
# Limite inferior permitido CANT                           -14.324219
# PRECIO_UNITARIO              -6499.204684
# COSTO_UNITARIO               -2821.614250
# COSTO_UNITARIO_CALCULADO    -15603.765678
# SUBTOTAL_PARTIDA            -21404.897036
# COSTO_TOTAL_CALCULADO       -15803.336348
# MARGEN_UNITARIO_CALCULADO   -14049.656995
# MARGEN_TOTAL_CALCULADO      -21519.643893
# dtype: float64

# %%
#obtenemos datos y los outliers se convierten en nulos en el dataframe
data3=cuantitativas[(y<= Limite_Superior)& (y>=Limmite_Inferior)]
data3
# Out:
#       CANT  PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0      1.0           434.48           52.80                     52.80
# 1      1.0          1264.05          327.18                    327.18
# 2      7.0           551.61          177.68                    177.68
# 3      1.0           140.00           38.96                     38.96
# 4      2.0           172.41          101.71                    101.71
# ...    ...              ...             ...                       ...
# 1421   6.0           712.00          102.31                    102.31
# 1422   6.0           718.60          104.69                    104.69
# 1423   3.0          2182.35            0.00                    596.55
# 1424   1.0          5909.84         1884.35                   1884.35
# 1425  10.0          1406.00            0.00                     80.66
#
#       SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# ...

# %%
#corroboramos valores nulos del dataframe
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# CANT                         28
# PRECIO_UNITARIO              29
# COSTO_UNITARIO               10
# COSTO_UNITARIO_CALCULADO      2
# SUBTOTAL_PARTIDA             36
# COSTO_TOTAL_CALCULADO         5
# MARGEN_UNITARIO_CALCULADO    13
# MARGEN_TOTAL_CALCULADO       24
# dtype: int64

# %%
#remplazammos valores atipicos(nulos ) del dataframe  con "mean"
#realizamos una copia del dataframe
data_clean=data3.copy()
data_clean=data_clean.fillna(round(data3.mean(),1))
data_clean
# Out:
#       CANT  PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0      1.0           434.48           52.80                     52.80
# 1      1.0          1264.05          327.18                    327.18
# 2      7.0           551.61          177.68                    177.68
# 3      1.0           140.00           38.96                     38.96
# 4      2.0           172.41          101.71                    101.71
# ...    ...              ...             ...                       ...
# 1421   6.0           712.00          102.31                    102.31
# 1422   6.0           718.60          104.69                    104.69
# 1423   3.0          2182.35            0.00                    596.55
# 1424   1.0          5909.84         1884.35                   1884.35
# 1425  10.0          1406.00            0.00                     80.66
#
#       SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# ...

# %%
#corroborar valores nulos del dataframe limpio

valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# CANT                         0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %% [markdown]
# prodecimiento cuantiles  para sustituir outliers en dataframe

# %%
#metodo aplicando cuartiles encuentro cuartiles 0.25  y  0.75
y=cuantitativas

percentiles25=y.quantile(0.25) #Q1
percentiles75=y.quantile(0.75) #Q2
iqr=percentiles75 - percentiles25

Limite_Superior_iqr=percentiles75 + 1.5*iqr
Limmite_Inferior_iqr=percentiles25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limmite_Inferior_iqr)
# Out:
# Limite superior permitido CANT                             8.50000
# PRECIO_UNITARIO               2954.86625
# COSTO_UNITARIO                 567.95000
# COSTO_UNITARIO_CALCULADO       807.81375
# SUBTOTAL_PARTIDA             10783.51250
# COSTO_TOTAL_CALCULADO         2971.36250
# MARGEN_UNITARIO_CALCULADO     2089.94625
# MARGEN_TOTAL_CALCULADO        7807.59750
# dtype: float64
# Limite inferior permitido CANT                           -3.50000
# PRECIO_UNITARIO              -927.40375
# COSTO_UNITARIO               -340.77000
# COSTO_UNITARIO_CALCULADO     -340.87625
# SUBTOTAL_PARTIDA            -4946.78750
# COSTO_TOTAL_CALCULADO       -1506.25750
# MARGEN_UNITARIO_CALCULADO    -621.22375
# MARGEN_TOTAL_CALCULADO      -3594.42250
# dtype: float64

# %%
#obtenemos datos limpios del df
data3_iqr=cuantitativas[(y<= Limite_Superior_iqr) & (y>=Limmite_Inferior_iqr)]
data3
# Out:
#       CANT  PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0      1.0           434.48           52.80                     52.80
# 1      1.0          1264.05          327.18                    327.18
# 2      7.0           551.61          177.68                    177.68
# 3      1.0           140.00           38.96                     38.96
# 4      2.0           172.41          101.71                    101.71
# ...    ...              ...             ...                       ...
# 1421   6.0           712.00          102.31                    102.31
# 1422   6.0           718.60          104.69                    104.69
# 1423   3.0          2182.35            0.00                    596.55
# 1424   1.0          5909.84         1884.35                   1884.35
# 1425  10.0          1406.00            0.00                     80.66
#
#       SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# ...

# %%
#se corroboran valores limpios
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# CANT                         169
# PRECIO_UNITARIO              127
# COSTO_UNITARIO               128
# COSTO_UNITARIO_CALCULADO     144
# SUBTOTAL_PARTIDA             159
# COSTO_TOTAL_CALCULADO        162
# MARGEN_UNITARIO_CALCULADO    132
# MARGEN_TOTAL_CALCULADO       168
# dtype: int64

# %%
#reemplazamos valores atipicos nulos del dataframe con mean 
#realizamos una copia del dataframe
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.mean(),1))
data4_iqr
# Out:
#       CANT  PRECIO_UNITARIO  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0      1.0           434.48           52.80                     52.80
# 1      1.0          1264.05          327.18                    327.18
# 2      7.0           551.61          177.68                    177.68
# 3      1.0           140.00           38.96                     38.96
# 4      2.0           172.41          101.71                    101.71
# ...    ...              ...             ...                       ...
# 1421   6.0           712.00          102.31                    102.31
# 1422   6.0           718.60          104.69                    104.69
# 1423   3.0          2182.35            0.00                    596.55
# 1424   1.0           942.70          108.00                    219.90
# 1425   2.4          1406.00            0.00                     80.66
#
#       SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# ...

# %%
#realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
data4_iqr.plot(kind='box', vert=False)
plt.title("valores_atipicos_dataframe")
plt.show() #dibujamos el diagrama

# %%
#realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
data4_iqr.boxplot(column='CANT', vert=False)
plt.title("valores_atipicos_dataframe")
plt.show() #dibujamos el diagrama

# %%
#realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
data4_iqr.boxplot(column='PRECIO_UNITARIO', vert=False)
plt.title("valores_atipicos_dataframe")
plt.show() #dibujamos el diagrama

# %%
#realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
data4_iqr.boxplot(column='COSTO_UNITARIO', vert=False)
plt.title("valores_atipicos_dataframe")
plt.show() #dibujamos el diagrama

# %%
#realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
data4_iqr.boxplot(column='COSTO_UNITARIO_CALCULADO', vert=False)
plt.title("valores_atipicos_dataframe")
plt.show() #dibujamos el diagrama

# %%
#realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
data4_iqr.boxplot(column='SUBTOTAL_PARTIDA', vert=False)
plt.title("valores_atipicos_dataframe")
plt.show() #dibujamos el diagrama

# %%
#realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
data4_iqr.boxplot(column='COSTO_TOTAL_CALCULADO', vert=False)
plt.title("valores_atipicos_dataframe")
plt.show() #dibujamos el diagrama

# %%
#realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
data4_iqr.boxplot(column='MARGEN_UNITARIO_CALCULADO', vert=False)
plt.title("valores_atipicos_dataframe")
plt.show() #dibujamos el diagrama

# %%
#realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
data4_iqr.boxplot(column='MARGEN_TOTAL_CALCULADO', vert=False)
plt.title("valores_atipicos_dataframe")
plt.show() #dibujamos el diagrama

# %%
#unimos el dataframe cuantitativo limpio con el df cualitativo

Datos_limpios= pd.concat([cualitativas, data4_iqr], axis=1)
Datos_limpios
# Out:
#      CVE_DOC   FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034  2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036  2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041  2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042  2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043  2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...         ...                        ...
# 1421  F39834  2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834  2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835  2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837  2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838  2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE       CVE_ART  \
# 0               PÚBLICO EN GENERAL      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS        TP0007
# 3             OMAR RODRIGUEZ GOMEZ        TP0001
# 4               PÚBLICO EN GENERAL       BP00242
# ...

# %%
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos
# Out:
# CVE_DOC                      0
# FECHA_DOC                    0
# NOMBRE_VENDEDOR              0
# NOMBRE_CLIENTE               0
# CVE_ART                      0
# DESCR                        0
# CANT                         0
# PRECIO_UNITARIO              0
# COSTO_UNITARIO               0
# COSTO_UNITARIO_CALCULADO     0
# SUBTOTAL_PARTIDA             0
# COSTO_TOTAL_CALCULADO        0
# MARGEN_UNITARIO_CALCULADO    0
# MARGEN_TOTAL_CALCULADO       0
# dtype: int64

# %%
#convertir df a csv
Datos_limpios.to_csv("datos y productos_nulo_limpio.csv")
